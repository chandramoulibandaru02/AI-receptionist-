# %%
try:
    import whisper
    model=whisper.load_model("tiny")
    result=model.transcribe(r"C:\Users\Chandramouli bandaru\OneDrive\Desktop\langchains\harvard.wav")
    print("Text is : ",result["text"])
except Exception as e:
    print(e)
# Out:
# [WinError 2] The system cannot find the file specified
# c:\Users\Chandramouli bandaru\anaconda3\envs\langchain\lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
1
# Out:
# 1

# %%
import os
import whisper
os.environ["PATH"] += os.pathsep + r"D:\ffmpeg\bin"
model = whisper.load_model("tiny")
path=r"C:\Users\Chandramouli bandaru\OneDrive\Desktop\langchains\autio.wav"
result = model.transcribe(path)
print("Text is:", result["text"])
# Out:
# Text is:  ciao Vermuoli

# %%
import whisper
os.environ["PATH"] += os.pathsep + r"D:\ffmpeg\bin"

try:
    model=whisper.load_model("tiny")
    
    print("text is : ",result["text"])
except Exception as e:
    print(e)
# Out:
# transcribe() missing 1 required positional argument: 'audio'

# %%
import os
import whisper

# fix ffmpeg path
os.environ["PATH"] += os.pathsep + r"D:\ffmpeg\bin"

try:
    model = whisper.load_model("tiny")
    
    result=whisper.transcribe(r"C:\Users\Chandramouli bandaru\OneDrive\Desktop\langchains\AI receptionist\live.wav")

    
    print("Text is:", result["text"])

except Exception as e:
    import traceback
    print("Error:", e)
    traceback.print_exc()
# Out:
# Error: transcribe() missing 1 required positional argument: 'audio'
# Traceback (most recent call last):
#   File "C:\Users\Chandramouli bandaru\AppData\Local\Temp\ipykernel_23436\2070165147.py", line 10, in <module>
#     result=whisper.transcribe(r"C:\Users\Chandramouli bandaru\OneDrive\Desktop\langchains\AI receptionist\live.wav")
# TypeError: transcribe() missing 1 required positional argument: 'audio'

# %%
import os
import whisper

# fix ffmpeg path
os.environ["PATH"] += os.pathsep + r"D:\ffmpeg\bin"

try:
    model = whisper.load_model("medium")
    
    result = model.transcribe(
        r"C:\Users\Chandramouli bandaru\OneDrive\Desktop\langchains\AI receptionist\live.wav"
    )
    
    print("Text is:", result["text"])

except Exception as e:
    import traceback
    print("Error:", e)
    traceback.print_exc()
# Out:
# c:\Users\Chandramouli bandaru\anaconda3\envs\langchain\lib\site-packages\whisper\__init__.py:69: UserWarning: C:\Users\Chandramouli bandaru\.cache\whisper\medium.pt exists, but the SHA256 checksum does not match; re-downloading the file
#   warnings.warn(
#   0%|▏                                     | 4.80M/1.42G [00:08<44:46, 567kiB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 os.environ["PATH"] += os.pathsep + r"D:\ffmpeg\bin"
#       7 try:
# ----> 8     model = whisper.load_model("medium")
#      10     result = model.transcribe(
#      11         r"C:\Users\Chandramouli bandaru\OneDrive\Desktop\langchains\AI receptionist\live.wav"
#      12     )
#      14     print("Text is:", result["text"])
#
# ...

# %%
import sounddevice as sd
from scipy.io.wavfile import write

fs = 44100  # sample rate
seconds = 5  # recording duration

print("🎤 Speak now...")
audio = sd.rec(int(seconds * fs), samplerate=fs, channels=1)
sd.wait()

write("live.wav", fs, audio)
print("Recording saved as live.wav")
# Out:
# 🎤 Speak now...
# Recording saved as live.wav
